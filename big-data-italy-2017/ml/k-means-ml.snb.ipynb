// %%
import scala.collection.mutable.HashMap
import org.apache.spark.ml.clustering.KMeans
import org.apache.spark.mllib.regression.LabeledPoint
import org.apache.spark.ml.linalg.Vectors
import org.apache.spark.ml.feature.Normalizer
val data = sc.textFile("/home/stavros/Downloads/wineQualityReds.csv")
 val header = data.first()
val parsedData = data.filter(row => row != header).map { data => 
val values = data.split(',')
(values(0), Vectors.dense(values.drop(1).map(_.toDouble)))
}.cache()
val dfPoints = parsedData.toDF("label","features")
val normalizer = new Normalizer()
  .setInputCol("features")
  .setOutputCol("n_features")

val lInfNormData = normalizer.transform(dfPoints, normalizer.p -> Double.PositiveInfinity)
// lInfNormData.show()
val normalized_data = lInfNormData.select($"label", $"n_features".as("features"))

val errors = new HashMap[Int,Double]()
 for (numClusters <- 2 to 20) {     
   val kmeans = new KMeans().setK(numClusters)
   .setFeaturesCol("n_features")
   .setMaxIter(50)
   val model = kmeans.fit(lInfNormData)
   val WSSSE = model.computeCost(lInfNormData)
   errors.put(numClusters, WSSSE)
}
// Out:
// import scala.collection.mutable.HashMap
// import org.apache.spark.ml.clustering.KMeans
// import org.apache.spark.mllib.regression.LabeledPoint
// import org.apache.spark.ml.linalg.Vectors
// import org.apache.spark.ml.feature.Normalizer
// data: org.apache.spark.rdd.RDD[String] = /home/stavros/Downloads/wineQualityReds.csv MapPartitionsRDD[6426] at textFile at <console>:165
// header: String = "","fixed.acidity","volatile.acidity","citric.acid","residual.sugar","chlorides","free.sulfur.dioxide","total.sulfur.dioxide","density","pH","sulphates","alcohol","quality"
// parsedData: org.apache.spark.rdd.RDD[(String, org.apache.spark.ml.linalg.Vector)] = MapPartitionsRDD[6428] at map at <console>:167
// dfPoints: org.apache.spark.sql.DataFrame = [label: string, features: vector]
// normalizer: org.apache.spark.ml.fea...

// %%
WSSSE
// Out:
// res207: Double = 107.14101429590055
// 107.14101429590055

// %%
errors.toArray
// Out:
// res209: Array[(Int, Double)] = Array((17,21.559666739049433), (8,35.70260943001307), (11,27.692201213342862), (20,19.34549475806726), (2,107.14101429590055), (5,48.53559329155385), (14,24.557777658418264), (4,56.78355364701449), (13,25.257836089219992), (16,22.194938026480422), (7,37.76941511328587), (10,30.71351096101113), (19,20.091797846238663), (18,21.021726370385895), (9,31.948719879861514), (3,75.79602680334075), (12,26.152586968386245), (15,23.018920156459714), (6,42.68206084715902))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonfc0875dbb8799ea7ccc283863a654193&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;981598573&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul981598573"><li>
//               <a href="#tab981598573-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab981598573-1"><i class="fa fa-dot-circle-o"/></a>
//             </li><li>
//               <a href="#tab981598573-2"><i class="fa fa-line-chart"/></a>
//             </li><li>
//               <a href="#tab981598573-3"><i class="fa fa-bar-chart"/></a>
//             </li><li>
//               <a href="#tab981598573-4"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab981598573"><div class="tab-pane" id="tab981598573-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon783af60ec6747ddb37afd03e7f4e42a3&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:17,&quot;_2&quot;:21.559666739049433},{&quot;_1&quot;:8,&quot;_2&quot;:35.70260943001307},{&quot;_1&quot;:11,&quot;_2&quot;:27.692201213342862},{&quot;_1&quot;:20,&quot;_2&quot;:19.34549475806726},{&quot;_1&quot;:2,&quot;_2&quot;:107.14101429590055},{&quot;_1&quot;:5,&quot;_2&quot;:48.53559329155385},{&quot;_1&quot;:14,&quot;_2&quot;:24.557777658418264},{&quot;_1&quot;:4,&quot;_2&quot;:56.78355364701449},{&quot;_1&quot;:13,&quot;_2&quot;:25.257836089219992},{&quot;_1&quot;:16,&quot;_2&quot;:22.194938026480422},{&quot;_1&quot;:7,&quot;_2&quot;:37.76941511328587},{&quot;_1&quot;:10,&quot;_2&quot;:30.71351096101113},{&quot;_1&quot;:19,&quot;_2&quot;:20.091797846238663},{&quot;_1&quot;:18,&quot;_2&quot;:21.021726370385895},{&quot;_1&quot;:9,&quot;_2&quot;:31.948719879861514},{&quot;_1&quot;:3,&quot;_2&quot;:75.79602680334075},{&quot;_1&quot;:12,&quot;_2&quot;:26.152586968386245},{&quot;_1&quot;:15,&quot;_2&quot;:23.018920156459714},{&quot;_1&quot;:6,&quot;_2&quot;:42.68206084715902}],&quot;genId&quot;:&quot;893467294&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["_1","_2"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon1fddf6f31a1f7d0af19e787ad814cfdc&quot;,&quot;initialValue&quot;:&quot;19&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon4c7f6d7cb4e8f7a55fc537e190f8ba82&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab981598573-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon539de456241ab6ab053dcc9c79c610b4&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:17,&quot;_2&quot;:21.559666739049433},{&quot;_1&quot;:8,&quot;_2&quot;:35.70260943001307},{&quot;_1&quot;:11,&quot;_2&quot;:27.692201213342862},{&quot;_1&quot;:20,&quot;_2&quot;:19.34549475806726},{&quot;_1&quot;:2,&quot;_2&quot;:107.14101429590055},{&quot;_1&quot;:5,&quot;_2&quot;:48.53559329155385},{&quot;_1&quot;:14,&quot;_2&quot;:24.557777658418264},{&quot;_1&quot;:4,&quot;_2&quot;:56.78355364701449},{&quot;_1&quot;:13,&quot;_2&quot;:25.257836089219992},{&quot;_1&quot;:16,&quot;_2&quot;:22.194938026480422},{&quot;_1&quot;:7,&quot;_2&quot;:37.76941511328587},{&quot;_1&quot;:10,&quot;_2&quot;:30.71351096101113},{&quot;_1&quot;:19,&quot;_2&quot;:20.091797846238663},{&quot;_1&quot;:18,&quot;_2&quot;:21.021726370385895},{&quot;_1&quot;:9,&quot;_2&quot;:31.948719879861514},{&quot;_1&quot;:3,&quot;_2&quot;:75.79602680334075},{&quot;_1&quot;:12,&quot;_2&quot;:26.152586968386245},{&quot;_1&quot;:15,&quot;_2&quot;:23.018920156459714},{&quot;_1&quot;:6,&quot;_2&quot;:42.68206084715902}],&quot;genId&quot;:&quot;573011153&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/scatterChart'],
//       function(playground, _magicscatterChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicscatterChart,
//     "o": {"x":"_1","y":"_2","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon2ffd2acaddde92c773a2a8835a4f224e&quot;,&quot;initialValue&quot;:&quot;19&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon28b2f04c668d2671718175b1df173986&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab981598573-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anona1c4f0bc83cd42753bfcf6351c66df06&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:17,&quot;_2&quot;:21.559666739049433},{&quot;_1&quot;:8,&quot;_2&quot;:35.70260943001307},{&quot;_1&quot;:11,&quot;_2&quot;:27.692201213342862},{&quot;_1&quot;:20,&quot;_2&quot;:19.34549475806726},{&quot;_1&quot;:2,&quot;_2&quot;:107.14101429590055},{&quot;_1&quot;:5,&quot;_2&quot;:48.53559329155385},{&quot;_1&quot;:14,&quot;_2&quot;:24.557777658418264},{&quot;_1&quot;:4,&quot;_2&quot;:56.78355364701449},{&quot;_1&quot;:13,&quot;_2&quot;:25.257836089219992},{&quot;_1&quot;:16,&quot;_2&quot;:22.194938026480422},{&quot;_1&quot;:7,&quot;_2&quot;:37.76941511328587},{&quot;_1&quot;:10,&quot;_2&quot;:30.7135109

// %%
   val kmeans = new KMeans().setK(2)
   .setFeaturesCol("n_features")
   .setMaxIter(50)
   val model = kmeans.fit(lInfNormData)
   val WSSSE = model.computeCost(lInfNormData)
// Out:
// kmeans: org.apache.spark.ml.clustering.KMeans = kmeans_c0089ec1f99b
// model: org.apache.spark.ml.clustering.KMeansModel = kmeans_c0089ec1f99b
// WSSSE: Double = 107.14101429590055

// %%
model.clusterCenters
// Out:
// res212: Array[org.apache.spark.ml.linalg.Vector] = Array([0.18039444291409718,0.011903512685698184,0.00538682352254432,0.052890252892119106,0.001927570269812699,0.3694765387729449,1.0,0.022183009281431215,0.0741005521280797,0.014625924011909038,0.22995980340258093,0.12500312447932746], [0.5788327370461465,0.0338725581836942,0.020011301098778453,0.1666257715575919,0.0056309725158454,0.40349633343290753,0.9675213942134802,0.06601698929968569,0.2180910512034508,0.04238828475464813,0.714994401855638,0.38312153624625206])
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonb090ce96d5c368f542947253d41f72ae&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;864701598&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul864701598"><li>
//               <a href="#tab864701598-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab864701598-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab864701598"><div class="tab-pane" id="tab864701598-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anone02c2e377cead72df38b975e76c7f5a4&quot;,&quot;dataInit&quot;:[{&quot;values&quot;:&quot;[D@56f7f1d6&quot;},{&quot;values&quot;:&quot;[D@1bb9d580&quot;}],&quot;genId&quot;:&quot;880610835&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["values"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond3045ce3df660fc63779e66ab05e35d0&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonb7da2e0903e760e99bca900d7b85b289&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab864701598-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonf3ea51213453988a1da3bad0558f9510&quot;,&quot;dataInit&quot;:[{&quot;values&quot;:&quot;[D@56f7f1d6&quot;},{&quot;values&quot;:&quot;[D@1bb9d580&quot;}],&quot;genId&quot;:&quot;398347789&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon1af19e8905c0ec653a633c27e69f9feb&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond3d788371a58b882241344710015dc46&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %%
import org.apache.spark.ml.feature.PCA
import org.apache.spark.ml.linalg.Vectors

val pca = new PCA()
  .setInputCol("features")
  .setOutputCol("pcaFeatures")
  .setK(2)
  .fit(normalized_data)


val result = pca.transform(normalized_data).select("pcaFeatures")
result.show(false)
// Out:
// +-------------------------------------------+
// |pcaFeatures                                |
// +-------------------------------------------+
// |[-0.3702973306866152,-0.33771637980173497] |
// |[-0.18712918469358497,-0.4023322671905787] |
// |[-0.22830404336207674,-0.30380330949811646]|
// |[-0.23880490950702832,-0.30385624143161144]|
// |[-0.3702973306866152,-0.33771637980173497] |
// |[-0.3103399519170776,-0.34436979708419047] |
// |[-0.19848360865860548,-0.28268066530572394]|
// |[-0.6977010617039199,-0.7043676334409302]  |
// |[-0.7960129637347033,-0.4784408899780102]  |
// |[-0.10492361385769952,-0.2037650030505796] |
// |[-0.1630245984212077,-0.2638485404888952]  |
// |[-0.10492361385769952,-0.2037650030505796] |
// |[-0.18529130939240113,-0.30476015011481344]|
// |[-0.4362691590601039,-0.31712672795491115] |
// |[-0.07537772221534685,-0.3966274942156468] |
// |[-0.07221040405907608,-0.3829401962619964] |
// |[-0.12518177227143848,-0.3750539093048038] |
// |[-0.21478281300432153,-0.3120605580593237] |
// |[-0.4183908983593498,-0.21372247490365845] |
// |[-0.2196085157598218,-0.33009489006235754] |
// +-------------------------------------------+
// only showing top 20 rows
//
// import org.apache.spark.ml.feature.PCA
// import org.apache.spark.ml.linalg.Vectors
// pca: org.apache.spark.ml.feature.PCAModel = pca_499329021c42
// result: org.apache.spark.sql.DataFrame = [pcaFeatures: vector]

// %%
result.rdd.collect().map{x => x.getAs[org.apache.spark.ml.linalg.DenseVector]("pcaFeatures").toArray}
.map { case Array(f1,f2) => (f1,f2) }
// Out:
// res216: Array[(Double, Double)] = Array((-0.3702973306866152,-0.33771637980173497), (-0.18712918469358497,-0.4023322671905787), (-0.22830404336207674,-0.30380330949811646), (-0.23880490950702832,-0.30385624143161144), (-0.3702973306866152,-0.33771637980173497), (-0.3103399519170776,-0.34436979708419047), (-0.19848360865860548,-0.28268066530572394), (-0.6977010617039199,-0.7043676334409302), (-0.7960129637347033,-0.4784408899780102), (-0.10492361385769952,-0.2037650030505796), (-0.1630245984212077,-0.2638485404888952), (-0.10492361385769952,-0.2037650030505796), (-0.18529130939240113,-0.30476015011481344), (-0.4362691590601039,-0.31712672795491115), (-0.07537772221534685,-0.3966274942156468), (-0.07221040405907608,-0.3829401962619964), (-0.12518177227143848,-0.3750539093048038), (-0.2147...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon6228f2fea524ddd6c35603d350940f79&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;534724743&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul534724743"><li>
//               <a href="#tab534724743-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab534724743-1"><i class="fa fa-dot-circle-o"/></a>
//             </li><li>
//               <a href="#tab534724743-2"><i class="fa fa-line-chart"/></a>
//             </li><li>
//               <a href="#tab534724743-3"><i class="fa fa-bar-chart"/></a>
//             </li><li>
//               <a href="#tab534724743-4"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab534724743"><div class="tab-pane" id="tab534724743-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon982637b3973580cc00f41746455873da&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:-0.3702973306866152,&quot;_2&quot;:-0.33771637980173497},{&quot;_1&quot;:-0.18712918469358497,&quot;_2&quot;:-0.4023322671905787},{&quot;_1&quot;:-0.22830404336207674,&quot;_2&quot;:-0.30380330949811646},{&quot;_1&quot;:-0.23880490950702832,&quot;_2&quot;:-0.30385624143161144},{&quot;_1&quot;:-0.3702973306866152,&quot;_2&quot;:-0.33771637980173497},{&quot;_1&quot;:-0.3103399519170776,&quot;_2&quot;:-0.34436979708419047},{&quot;_1&quot;:-0.19848360865860548,&quot;_2&quot;:-0.28268066530572394},{&quot;_1&quot;:-0.6977010617039199,&quot;_2&quot;:-0.7043676334409302},{&quot;_1&quot;:-0.7960129637347033,&quot;_2&quot;:-0.4784408899780102},{&quot;_1&quot;:-0.10492361385769952,&quot;_2&quot;:-0.2037650030505796},{&quot;_1&quot;:-0.1630245984212077,&quot;_2&quot;:-0.2638485404888952},{&quot;_1&quot;:-0.10492361385769952,&quot;_2&quot;:-0.2037650030505796},{&quot;_1&quot;:-0.18529130939240113,&quot;_2&quot;:-0.30476015011481344},{&quot;_1&quot;:-0.4362691590601039,&quot;_2&quot;:-0.31712672795491115},{&quot;_1&quot;:-0.07537772221534685,&quot;_2&quot;:-0.3966274942156468},{&quot;_1&quot;:-0.07221040405907608,&quot;_2&quot;:-0.3829401962619964},{&quot;_1&quot;:-0.12518177227143848,&quot;_2&quot;:-0.3750539093048038},{&quot;_1&quot;:-0.21478281300432153,&quot;_2&quot;:-0.3120605580593237},{&quot;_1&quot;:-0.4183908983593498,&quot;_2&quot;:-0.21372247490365845},{&quot;_1&quot;:-0.2196085157598218,&quot;_2&quot;:-0.33009489006235754},{&quot;_1&quot;:-0.23168025046956564,&quot;_2&quot;:-0.5069304750805553},{&quot;_1&quot;:-0.16839799859198534,&quot;_2&quot;:-0.3552295551076598},{&quot;_1&quot;:-0.33964268733380537,&quot;_2&quot;:-0.2861506551254674},{&quot;_1&quot;:-0.16599327472338757,&quot;_2&quot;:-0.16503267674680164},{&quot;_1&quot;:-0.33789037416593765,&quot;_2&quot;:-0.5431422794851345},{&quot;_1&quot;:-0.540045043016092,&quot;_2&quot;:-0.481613599495535},{&quot;_1&quot;:-1.2161096947077534,&quot;_2&quot;:-0.30351241325164735},{&quot;_1&quot;:-0.33964268733380537,&quot;_2&quot;:-0.2861506551254674},{&quot;_1&quot;:-0.36092788600635817,&quot;_2&quot;:-0.41545746297840574},{&quot;_1&quot;:-0.8872601703721493,&quot;_2&quot;:-0.46990415121843515},{&quot;_1&quot;:-0.1285305538969372,&quot;_2&quot;:-0.2437292855021279},{&quot;_1&quot;:-0.3898147973925092,&quot;_2&quot;:-0.6094810387207398},{&quot;_1&quot;:-0.08159831851840255,&quot;_2&quot;:-0.17174116793048383},{&quot;_1&quot;:-0.16728780130389498,&quot;_2&quot;:-0.5116160728893848},{&quot;_1&quot;:-0.2091165114954605,&quot;_2&quot;:-0.29193913748793404},{&quot;_1&quot;:-0.7898337728904655,&quot;_2&quot;:-0.2522268341782209},{&quot;_1&quot;:-0.9705296926954943,&quot;_2&quot;:-0.1668418863730226},{&quot;_1&quot;:-0.47688849026210756,&quot;_2&quot;:-0.4380127528582167},{&quot;_1&quot;:-0.6313455617441341,&quot;_2&quot;:-0.3680861085374763},{&quot;_1&quot;:-0.12592383846475907,&quot;_2&quot;:-0.17351323375906166},{&quot;_1&quot;:-0.12592383846475907,&quot;_2&quot;:-0.17351323375906166},{&quot;_1&quot;:-0.28002014684206167,&quot;_2&quot;:-0.3872060063884098},{&quot;_1&quot;:-1.0498056379219904,&quot;_2&quot;:-0.5305396219323714},{&quot;_1&quot;:-0.6118989881281484,&quot;_2&quot;:-0.3833286715957855},{&quot;_1&quot;:-1.1879435438571362,&quot;_2&quot;:-0.403661960069288},{&quot;_1&quot;:-0.17364708793154507,&quot;_2&quot;:-0.16130441866317857},{&quot;_1&quot;:-0.07960960272024967,&quot;_2&quot;:-0.23213464001995224},{&quot;_1&quot;:-0.35668622222729646,&quot;_2&quot;:-0.3364965952651918},{&quot;_1&quot;:-1.0433526395730603,&quot;_2&quot;:-0.3794554495759797},{&quot;_1&quot;:-0.0822007246593476,&quot;_2&quot;:-0.16625085984286622},{&quot;_1&quot;:-0.5705265088138783,&quot;_2&quot;:-0.16534351597717323},{&quot;_1&quot;:-0.8898170886243876,&quot;_2&quot;:-0.5084713019444042},{&quot;_1&quot;:-0.9431449590442121,&quot;_2&quot;:-0.40011788860230146},{&quot;_1&quot;:-0.08 ...
